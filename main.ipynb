# %%
from lib import run

# %%
run('cathedral.jpg')
# Out:
# 341
# Algorithm Run Parameters: Trials: 5, Pixel Width: 256, NCC Max: 0.96
# Total number of pixels in im1 (excluding channels): 96612
# Pyramid size 3
# Iteration 0, Shape of images: (73, 83) offset: (0, 0)
# Search X range(-15, 16)
# Search Y range(-15, 16)
# 100%|██████████| 961/961 [00:00<00:00, 19270.83it/s]
# Best Running offset (1, 1)
# Iteration 1, Shape of images: (146, 166) offset: (2, 2)
# Search X range(0, 2)
# Search Y range(0, 2)
# 100%|██████████| 4/4 [00:00<00:00, 4233.46it/s]
# Best Running offset (2, 2)
# Iteration 2, Shape of images: (291, 332) offset: (4, 4)
# Search X range(1, 3)
# Search Y range(1, 3)
# 100%|██████████| 4/4 [00:00<00:00, 1926.87it/s]
# Best Running offset (4, 4)
# Returning (4, 4) 0.907936448489866
# Total number of pixels in im1 (excluding channels): 96612
# Pyramid size 3
# Iteration 0, Shape of images: (73, 83) offset: (0, 0)
# Search X range(-15, 16)
# Search Y range(-15, 16)
# 100%|██████████| 961/961 [00:00<00:00, 21418.84it/s]
# ...

# %%
run('onion_church.tif')
# Out:
# 3215
# Algorithm Run Parameters: Trials: 5, Pixel Width: 256, NCC Max: 0.96
# Total number of pixels in im1 (excluding channels): 8786595
# Pyramid size 6
# Iteration 0, Shape of images: (86, 100) offset: (0, 0)
# Search X range(-15, 16)
# Search Y range(-15, 16)
# 100%|██████████| 961/961 [00:00<00:00, 22933.39it/s]
# Best Running offset (1, 2)
# Iteration 1, Shape of images: (171, 201) offset: (2, 4)
# Search X range(0, 2)
# Search Y range(1, 3)
# 100%|██████████| 4/4 [00:00<00:00, 3430.92it/s]
# Best Running offset (2, 4)
# Iteration 2, Shape of images: (342, 402) offset: (4, 8)
# Search X range(1, 3)
# Search Y range(3, 5)
# 100%|██████████| 4/4 [00:00<00:00, 1401.61it/s]
# Best Running offset (4, 8)
# Iteration 3, Shape of images: (683, 804) offset: (8, 16)
# Search X range(3, 5)
# Search Y range(7, 9)
# 100%|██████████| 4/4 [00:00<00:00, 410.68it/s]
# Best Running offset (8, 16)
# Iteration 4, Shape of images: (1366, 1608) offset: (16, 32)
# Search X range(7, 9)
# ...

# %%
run('emir.tif')
# Out:
# 3209
# Algorithm Run Parameters: Trials: 5, Pixel Width: 256, NCC Max: 0.96
# Total number of pixels in im1 (excluding channels): 8590892
# Pyramid size 6
# Iteration 0, Shape of images: (85, 98) offset: (0, 0)
# Search X range(-15, 16)
# Search Y range(-15, 16)
# 100%|██████████| 961/961 [00:00<00:00, 34771.92it/s]
# Best Running offset (1, 1)
# Iteration 1, Shape of images: (170, 197) offset: (2, 2)
# Search X range(0, 2)
# Search Y range(0, 2)
# 100%|██████████| 4/4 [00:00<00:00, 3226.39it/s]
# Best Running offset (2, 2)
# Iteration 2, Shape of images: (341, 394) offset: (4, 4)
# Search X range(1, 3)
# Search Y range(1, 3)
# 100%|██████████| 4/4 [00:00<00:00, 1543.16it/s]
# Best Running offset (4, 4)
# Iteration 3, Shape of images: (682, 787) offset: (8, 8)
# Search X range(3, 5)
# Search Y range(3, 5)
# 100%|██████████| 4/4 [00:00<00:00, 214.33it/s]
# Best Running offset (8, 8)
# Iteration 4, Shape of images: (1364, 1574) offset: (16, 16)
# Search X range(7, 9)
# ...

# %%
run('monastery.jpg')
# Out:
# 341
# Algorithm Run Parameters: Trials: 5, Pixel Width: 256, NCC Max: 0.96
# Total number of pixels in im1 (excluding channels): 96903
# Pyramid size 3
# Iteration 0, Shape of images: (73, 83) offset: (0, 0)
# Search X range(-15, 16)
# Search Y range(-15, 16)
# 100%|██████████| 961/961 [00:00<00:00, 23833.25it/s]
# Best Running offset (0, -1)
# Iteration 1, Shape of images: (146, 166) offset: (0, -2)
# Search X range(-1, 1)
# Search Y range(-2, 0)
# 100%|██████████| 4/4 [00:00<00:00, 1776.87it/s]
# Best Running offset (0, -2)
# Iteration 2, Shape of images: (291, 333) offset: (0, -4)
# Search X range(-1, 1)
# Search Y range(-3, -1)
# 100%|██████████| 4/4 [00:00<00:00, 1999.91it/s]
# Best Running offset (0, -4)
# Returning (0, -4) 0.9082828615083003
# Total number of pixels in im1 (excluding channels): 96903
# Pyramid size 3
# Iteration 0, Shape of images: (73, 83) offset: (0, 0)
# Search X range(-15, 16)
# Search Y range(-15, 16)
# ...

# %%
run('sculpture.tif')
# Out:
# 3257
# Algorithm Run Parameters: Trials: 5, Pixel Width: 256, NCC Max: 0.96
# Total number of pixels in im1 (excluding channels): 8943870
# Pyramid size 6
# Iteration 0, Shape of images: (86, 101) offset: (0, 0)
# Search X range(-15, 16)
# Search Y range(-15, 16)
# 100%|██████████| 961/961 [00:00<00:00, 32312.50it/s]
# Best Running offset (0, 1)
# Iteration 1, Shape of images: (173, 202) offset: (0, 2)
# Search X range(-1, 1)
# Search Y range(0, 2)
# 100%|██████████| 4/4 [00:00<00:00, 3149.47it/s]
# Best Running offset (0, 2)
# Iteration 2, Shape of images: (346, 404) offset: (0, 4)
# Search X range(-1, 1)
# Search Y range(1, 3)
# 100%|██████████| 4/4 [00:00<00:00, 1974.02it/s]
# Best Running offset (0, 4)
# Iteration 3, Shape of images: (692, 808) offset: (0, 8)
# Search X range(-1, 1)
# Search Y range(3, 5)
# 100%|██████████| 4/4 [00:00<00:00, 357.14it/s]
# Best Running offset (0, 8)
# Iteration 4, Shape of images: (1384, 1615) offset: (0, 16)
# Search X range(-1, 1)
# ...
